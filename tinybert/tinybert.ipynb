# %%
# Cell 1: Import necessary libraries
import pandas as pd
import json
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
import torch
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import numpy as np

# %%
# Cell 2: Load the data
train_json_path = 'C:\\Users\\harih\\Downloads\\annotations_v2\\semeval2024_dev_release\\subtask1\\train.json'
val_json_path = 'C:\\Users\\harih\\Downloads\\annotations_v2\\semeval2024_dev_release\\subtask1\\validation.json'
dev_unlabel_json_path = 'C:\\Users\\harih\\Downloads\\annotations_v2\\semeval2024_dev_release\\subtask1\\dev_unlabeled.json'
ar_json_path = 'C:\\Users\\harih\\Downloads\\datasets\\test_data\\ar_subtask1_test_unlabeled.json'
bg_json_path = 'C:\\Users\\harih\\Downloads\\datasets\\test_data\\bg_subtask1_test_unlabeled.json'
mk_json_path = 'C:\\Users\\harih\\Downloads\\datasets\\test_data\\mk_subtask1_test_unlabeled.json'
en_json_path = 'C:\\Users\\harih\\Downloads\\datasets\\test_data\\en_subtask1_test_unlabeled.json'

with open(train_json_path, 'r', encoding='utf-8') as f:
    train_json_data = json.load(f)
with open(val_json_path, 'r', encoding='utf-8') as f:
    val_data = json.load(f)
with open(dev_unlabel_json_path, 'r', encoding='utf-8') as f:
    dev_unlabel_data = json.load(f)
with open(ar_json_path, 'r', encoding='utf-8') as f:
    ar_data = json.load(f)
with open(bg_json_path, 'r', encoding='utf-8') as f:
    bg_data = json.load(f)
with open(mk_json_path, 'r', encoding='utf-8') as f:
    mk_data = json.load(f)
with open(en_json_path, 'r', encoding='utf-8') as f:
    en_data = json.load(f)

# %%
# Cell 3: Preprocess the data (adjusted)
# Extract texts and labels from the JSON data
def extract_texts_and_labels(json_data):
    texts = [item['text'] for item in json_data]
    labels = [item['labels'] for item in json_data]
    return texts, labels

train_texts, train_labels = extract_texts_and_labels(train_json_data)
val_texts, val_labels = extract_texts_and_labels(val_data)

# Binarize the labels
mlb = MultiLabelBinarizer()
train_labels = mlb.fit_transform(train_labels)
val_labels = mlb.transform(val_labels)

# Create a custom dataset class
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx]).float()  # Ensure labels are float tensors
        return item

    def __len__(self):
        return len(self.labels)

# Tokenize the texts
tokenizer = BertTokenizer.from_pretrained("prajjwal1/bert-tiny")
train_encodings = tokenizer(train_texts, truncation=True, padding=True, max_length=512)
val_encodings = tokenizer(val_texts, truncation=True, padding=True, max_length=512)

train_dataset = Dataset(train_encodings, train_labels)
val_dataset = Dataset(val_encodings, val_labels)

# %%
# Cell 4: Tokenizer and model initialization (adjusted)
tokenizer = BertTokenizer.from_pretrained("prajjwal1/bert-tiny")
model = BertForSequenceClassification.from_pretrained("prajjwal1/bert-tiny", num_labels=len(mlb.classes_))

# Ensure the model's output logits are properly shaped for multi-label classification
model.config.problem_type = "multi_label_classification"
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at prajjwal1/bert-tiny and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Cell 5: Define the compute_metrics function (adjusted)
def compute_metrics(p):
    preds = (p.predictions > 0.3).astype(int)  # Adjust the threshold to 0.3
    labels = p.label_ids
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='micro')  # Use 'micro' average for multi-label
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
# Cell 6: Training arguments and trainer (adjusted)
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=50,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=64,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    evaluation_strategy="epoch",
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics
)
# Out:
# C:\Users\harih\AppData\Roaming\Python\Python38\site-packages\transformers\training_args.py:1494: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='21900' max='21900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [21900/21900 18:34, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.218860</td>
#       <td>0.186000</td>
#       <td>0.240828</td>
#       <td>0.571429</td>
#       <td>0.152563</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0
style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8/8 00:01]
#     </div>
# {'eval_loss': 0.2919755280017853,
#  'eval_accuracy': 0.184,
#  'eval_f1': 0.3790087463556851,
#  'eval_precision': 0.4878048780487805,
#  'eval_recall': 0.3098927294398093,
#  'eval_runtime': 2.473,
#  'eval_samples_per_second': 202.185,
#  'eval_steps_per_second': 3.235,
#  'epoch': 50.0}

# %%
# Cell 8: Prediction function (adjusted)
def predict_labels(texts, ids, model, tokenizer):
    encodings = tokenizer(texts, truncation=True, padding=True, return_tensors='pt', max_length=512)
    dataset = Dataset(encodings, [[0] * len(mlb.classes_)] * len(texts))  # Dummy labels since we are predicting
    trainer = Trainer(model=model)
    predictions = trainer.predict(dataset)
    predicted_probs = predictions.predictions
    predicted_labels = (predicted_probs > 0.3).astype(int)  # Adjust the threshold to 0.3
    return [{"id": id_, "labels": labels} for id_, labels in zip(ids, mlb.inverse_transform(predicted_labels))]

# %%
# Cell 9: Predict and save the results
ar_texts = [item['text'] for item in ar_data]
bg_texts = [item['text'] for item in bg_data]
mk_texts = [item['text'] for item in mk_data]
en_texts = [item['text'] for item in en_data]
dev_texts = [item['text'] for item in dev_unlabel_data]

ar_ids = [item['id'] for item in ar_data]
bg_ids = [item['id'] for item in bg_data]
mk_ids = [item['id'] for item in mk_data]
en_ids = [item['id'] for item in en_data]
dev_ids = [item['id'] for item in dev_unlabel_data]

ar_predictions = predict_labels(ar_texts, ar_ids, model, tokenizer)
bg_predictions = predict_labels(bg_texts, bg_ids, model, tokenizer)
mk_predictions = predict_labels(mk_texts, mk_ids, model, tokenizer)
en_predictions = predict_labels(en_texts, en_ids, model, tokenizer)
dev_predictions = predict_labels(dev_texts, dev_ids, model, tokenizer)

with open('C:\\Users\\harih\\Downloads\\tinybert\\predictions_ar.json', 'w') as f:
    json.dump(ar_predictions, f)
with open('C:\\Users\\harih\\Downloads\\tinybert\\predictions_bg.json', 'w') as f:
    json.dump(bg_predictions, f)
with open('C:\\Users\\harih\\Downloads\\tinybert\\predictions_mk.json', 'w') as f:
    json.dump(mk_predictions, f)
with open('C:\\Users\\harih\\Downloads\\tinybert\\predictions_en.json', 'w') as f:
    json.dump(en_predictions, f)
with open('C:\\Users\\harih\\Downloads\\tinybert\\predictions_dev.json', 'w') as f:
    json.dump(dev_predictions, f)

print(f"AR Predictions: {ar_predictions}")
print(f"BG Predictions: {bg_predictions}")
print(f"MK Predictions: {mk_predictions}")
print(f"EN Predictions: {en_predictions}")
print(f"DEV Predictions: {dev_predictions}")
# Out:
# C:\Users\harih\AppData\Local\Temp\ipykernel_552\2986801062.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# AR Predictions: [{'id': '00001', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00002', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00003', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00004', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00005', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00006', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00008', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00009', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00011', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00012', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00016', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00017', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00019', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00020', 'labels': ('Name calling/Labeling',)}, {'id': '00021', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00022', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00023', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00024', 'labels': ('Thought-terminating cliché',)}, {'id': '00025', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00027', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00028', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00030', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00032', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00034', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00035', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00037', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00039', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00040', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00042', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00043', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00044', 'labels': ('Thought-terminating cliché',)}, {'id': '00046', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00047', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00048', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00049', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00050', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00051', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00052', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00053', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00054', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00055', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00056', 'labels': ('Thought-terminating cliché',)}, {'id': '00057', 'labels': ('Thought-terminating cliché',)}, {'id': '00058', 'labels': ('Name calling/Labeling', 'Repetition', 'Thought-terminating cliché')}, {'id': '00060', 'labels': ('Name calling/Labeling', 'Thought-terminating cliché')}, {'id': '00061', 'labels': ('Name calling/Labeling', 'Thought-terminating cli ...
# BG Predictions: [{'id': 'bg_mk_memes_83', 'labels': ('Loaded Language', 'Smears')}, {'id': 'bg_mk_memes_104', 'labels': ('Loaded Language',)}, {'id': 'bg_mk_memes
 'labels': ('Loaded Language', 'Name calling/Labeling')}, {'id': '78418', 'labels': ('Loaded Language',)}, {'id': '76302', 'labels': ('Smears',)}, {'id': '71408', 'labels': ('Appeal to authority', 'Smears')}, {'id': '77150', 'labels': ('Appeal to authority', 'Glittering generalities (Virtue)', 'Name calling/Labeling')}, {'id': '64980', 'labels': ('Smears',)}, {'id': '68743', 'labels': ()}, {'id': '70286', 'labels': ()}, {'id': '63190', 'labels': ('Glittering generalities (Virtue)', 'Name calling/Labeling')}, {'id': '65826', 'labels': ('Loaded Language', 'Name calling/Labeling', 'Smears')}, {'id': '69214', 'labels': ('Appeal to authority',)}, {'id': '67341', 'labels': ('Smears',)}, {'id': '66148', 'labels': ()}, {'id': '65134', 'labels': ('Loaded Language', 'Name calling/Labeling', 'Smears')}, {'id': '67462', 'labels': ('Appeal to authority', 'Flag-waving')}, {'id': '78972', 'labels': ('Flag-waving', 'Loaded Language', 'Slogans')}, {'id': '70300', 'labels': ('Name calling/Labeling', 'Smears')}, {'id': '63116', 'labels': ('Slogans',)}, {'id': '64628', 'labels': ()}, {'id': '69811', 'labels': ()}, {'id': '76176', 'labels': ('Loaded Language', 'Name calling/Labeling')}, {'id': '68374', 'labels': ('Smears',)}, {'id': '76761', 'labels': ('Name calling/Labeling',)}, {'id': '75955', 'labels': ()}, {'id': '66142', 'labels': ('Loaded Language',)}, {'id': '65689', 'labels': ('Smears',)}, {'id': '70642', 'labels': ...
# DEV Predictions: [{'id': '63292', 'labels': ()}, {'id': '70419', 'labels': ('Loaded Language', 'Name calling/Labeling')}, {'id': '63673', 'labels': ('Loaded Language', 'Smears')}, {'id': '71297', 'labels': ()}, {'id': '66340', 'labels': ('Loaded Language', 'Smears')}, {'id': '77304', 'labels': ()}, {'id': '76719', 'labels': ('Smears',)}, {'id': '78621', 'labels': ()}, {'id': '64354', 'labels': ('Black-and-white Fallacy/Dictatorship', 'Loaded Language')}, {'id': '69527', 'labels': ()}, {'id': '63834', 'labels': ('Smears',)}, {'id': '63225', 'labels': ('Appeal to authority',)}, {'id': '78675', 'labels': ()}, {'id': '66933', 'labels': ('Loaded Language',)}, {'id': '78661', 'labels': ('Loaded Language',)}, {'id': '69180', 'labels': ('Loaded Language',)}, {'id': '78636', 'labels': ('Name calling/Labeling',)}, {'id': '68040', 'labels': ('Loaded Language',)}, {'id': '75948', 'labels': ('Smears',)}, {'id': '76218', 'labels': ()}, {'id': '66685', 'labels': ()}, {'id': '69589', 'labels': ()}, {'id': '64559', 'labels': ('Doubt',)}, {'id': '66414', 'labels': ()}, {'id': '63891', 'labels': ('Name calling/Labeling',)}, {'id': '70213', 'labels': ('Glittering generalities (Virtue)', 'Name calling/Labeling')}, {'id': '77611', 'labels': ('Name calling/Labeling', 'Smears')}, {'id': '79093', 'labels': ('Loaded Language',)}, {'id': '76182', 'labels': ('Smears',)}, {'id': '71662', 'labels': ('Loaded Language',)}, {'id': '76312', 'labels': ('Loaded Language', 'Name calling/Labeling')}, {'id': '65051', 'labels': ('Smears',)}, {'id': '63970', 'labels': ('Smears',)}, {'id': '78841', 'labels': ('Appeal to authority', 'Name calling/Labeling', 'Smears')}, {'id': '77118', 'labels': ()}, {'id': '66740', 'labels': ()}, {'id': '63681', 'labels': ('Appeal to authority', 'Slogans')}, {'id': '79072', 'labels': ('Appeal to authority',)}, {'id': '65761', 'labels': ('Name calling/Labeling',)}, {'id': '77788', 'labels': ('Appeal to authority', 'Loaded Language', 'Name calling/Labeling', 'Slogans')}, {'id': '79499', 'labels': ()}, {'id': '64790', 'labels': ('Loaded Language', 'Name calling/Labeling', 'Smears')}, {'id': '76852', 'labels': ('Loaded Language', 'Smears')}, {'id': '69117', 'labels': ('Loaded Language', 'Name calling/Labeling', 'Smears')}, {'id': '79893', 'labels': ('Flag-waving', 'Loaded Language')}, {'id': '69421', 'labels': ()}, {'id': '75874', 'labels': ('Appeal to authority', 'Loaded Language', 'Thought-terminating cliché')}, {'id': '64763', 'labels': ()}, {'id': '70333', 'labels': ()}, {'id': '76253', 'labels': ('Name calling/Labeling',)}, {'id': '75939', 'labels': ('Loaded Language',)}, {'id': '76386', 'labels': ('Name calling/Labeling',)}, {'id': '78681', 'labels': ()}, {'id': '67822', 'labels': ('Loaded Language', 'Slogans')}, {'id': '78143', 'labels': ('Loaded Language',)}, {'id': '70136', 'labels': ('Smears',)}, {'id': '68057', 'labels': ()}, {'id': '69265', 'labels': ('Appeal to authority', 'Flag-waving', 'Loaded Language', 'Name calling/Labeling', 'Slogans')}, {'id': '66356', 'labels': ('Smears',)}, {'id': '63296', 'labels': ('Glittering generalities (Virtue)', 'Name calling/Labeling')}, {'id': '78860', 'labels': ('Smears',)}, {'id': '68880', 'labels': ('Smears',)}, {'id': '71739', 'labels': ('Smears',)}, {'id': '79258', 'labels': ('Smears',)}, {'id': '65711', 'labels': ('Loaded Language',)}, {'id': '77546', 'labels': ('Appeal to authority', 'Flag-waving')}, {'id': '77055', 'labels': ('Loaded Language',)}, {'id': '65125', 'labels': ('Name calling/Labeling', 'Smears')}, {'id': '66288', 'labels': ('Loaded Language', 'Name calling/Labeling', 'Smears')}, {'id': '71706', 'labels': ('Appeal to authority', 'Name calling/Labeling', 'Smears')}, {'id': '77566', 'labels': ()}, {'id': '77632', 'labels': ()}, {'id': '78153', 'labels': ('Name calling/Labeling', 'Smears')}, {'id': '77779', 'labels': ('Appeal to authority', 'Smears')}, {'id': '70773', 'labels': ()}, {'id': '68820', 'labels': ()}, {'id': '65736', 'labels': ('Name calling/Labeling',)}, {'id': ' ...

# %%
# !python C:\Users\harih\Downloads\subtask_1_2a.py -g C:\Users\harih\Downloads\gold_labels_ar_bg_md_version2\test_subtask1_bg.json -p C:\Users\harih\Downloads\tinybert\predictions_bg.json
# Out:
# f1_h=0.29873	prec_h=0.40312	rec_h=0.23728

# %%
# !python C:\Users\harih\Downloads\subtask_1_2a.py -g C:\Users\harih\Downloads\gold_labels_ar_bg_md_version2\test_subtask1_ar.json -p C:\Users\harih\Downloads\tinybert\predictions_ar.json
# Out:
# f1_h=0.27689	prec_h=0.19332	rec_h=0.48772

# %%
# !python C:\Users\harih\Downloads\subtask_1_2a.py -g C:\Users\harih\Downloads\dev_gold_labels\dev_gold_labels\dev_subtask1_en.json -p C:\Users\harih\Downloads\tinybert\predictions_dev.json
# Out:
# f1_h=0.48558	prec_h=0.64096	rec_h=0.39084

# %%
# !python C:\Users\harih\Downloads\subtask_1_2a.py -g C:\Users\harih\Downloads\gold_labels_ar_bg_md_version2\test_subtask1_md.json -p C:\Users\harih\Downloads\tinybert\predictions_mk.json
# Out:
# f1_h=0.37085	prec_h=0.44852	rec_h=0.31611
