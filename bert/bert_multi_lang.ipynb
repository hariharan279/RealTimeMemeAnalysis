# %%
import pandas as pd
import json
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
import torch
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import numpy as np

# %%
train_json_path = 'C:\\Users\\harih\\Downloads\\annotations_v2\\semeval2024_dev_release\\subtask1\\train.json'
val_json_path = 'C:\\Users\\harih\\Downloads\\annotations_v2\\semeval2024_dev_release\\subtask1\\validation.json'
dev_unlabel_json_path = 'C:\\Users\\harih\\Downloads\\annotations_v2\\semeval2024_dev_release\\subtask1\\dev_unlabeled.json'
ar_json_path = 'C:\\Users\\harih\\Downloads\\datasets\\test_data\\ar_subtask1_test_unlabeled.json'
bg_json_path = 'C:\\Users\\harih\\Downloads\\datasets\\test_data\\bg_subtask1_test_unlabeled.json'
mk_json_path = 'C:\\Users\\harih\\Downloads\\datasets\\test_data\\mk_subtask1_test_unlabeled.json'
en_json_path = 'C:\\Users\\harih\\Downloads\\datasets\\test_data\\en_subtask1_test_unlabeled.json'

with open(train_json_path, 'r', encoding='utf-8') as f:
    train_json_data = json.load(f)
with open(val_json_path, 'r', encoding='utf-8') as f:
    val_data = json.load(f)
with open(dev_unlabel_json_path, 'r', encoding='utf-8') as f:
    dev_unlabel_data = json.load(f)
with open(ar_json_path, 'r', encoding='utf-8') as f:
    ar_data = json.load(f)
with open(bg_json_path, 'r', encoding='utf-8') as f:
    bg_data = json.load(f)
with open(mk_json_path, 'r', encoding='utf-8') as f:
    mk_data = json.load(f)
with open(en_json_path, 'r', encoding='utf-8') as f:
    en_data = json.load(f)

# %%
mlb = MultiLabelBinarizer()
train_texts = [item['text'] for item in train_json_data]
train_labels = mlb.fit_transform([item['labels'] for item in train_json_data])
val_texts = [item['text'] for item in val_data]
val_labels = mlb.transform([item['labels'] for item in val_data])

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')

train_encodings = tokenizer(train_texts, truncation=True, padding=True, max_length=512)
val_encodings = tokenizer(val_texts, truncation=True, padding=True, max_length=512)
# Out:
# C:\Users\harih\AppData\Roaming\Python\Python38\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\harih\.cache\huggingface\hub\models--bert-base-multilingual-cased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx]).float()
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = Dataset(train_encodings, train_labels)
val_dataset = Dataset(val_encodings, val_labels)

# %%
model = BertForSequenceClassification.from_pretrained('bert-base-multilingual-cased', num_labels=len(mlb.classes_), problem_type="multi_label_classification")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def compute_metrics(p):
    # Convert predictions to multilabel format
    preds = (p.predictions > 0.5).astype(int)
    
    precision, recall, f1, _ = precision_recall_fscore_support(p.label_ids, preds, average='weighted')
    acc = accuracy_score(p.label_ids, preds)
    return {"accuracy": acc, "f1": f1, "precision": precision, "recall": recall}

training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=10,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
)

# %%
print(f"Train Dataset Size: {len(train_dataset)}")
print(f"Validation Dataset Size: {len(val_dataset)}")
# Out:
# Train Dataset Size: 7000
# Validation Dataset Size: 500

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='8750' max='8750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8750/8750 26:06, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.308100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.235100</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.226200</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.228700</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.225100</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.215000</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.219900</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.209400</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.207100</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.200200</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.194100</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.188800</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.181600</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.175800</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.164700</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.164300</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.157500</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=8750, training_loss=0.2044293491908482, metrics={'train_runtime': 1567.2624, 'train_samples_per_second': 44.664, 'train_steps_per_second': 5.583, 'total_flos': 1.349176059e+16, 'train_loss': 0.2044293491908482, 'epoch': 10.0})

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 00:03]
#     </div>
# C:\Users\harih\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'eval_loss': 0.24761347472667694,
#  'eval_accuracy': 0.208,
#  'eval_f1': 0.22597866390507823,
#  'eval_precision': 0.37971374089869964,
#  'eval_recall': 0.18951132300357568,
#  'eval_runtime': 4.1195,
#  'eval_samples_per_second': 121.373,
#  'eval_steps_per_second': 15.293,
#  'epoch': 10.0}

# %%
def predict_labels(texts, ids, model, tokenizer):
    encodings = tokenizer(texts, truncation=True, padding=True, return_tensors='pt', max_length=512)
    dataset = Dataset(encodings, [[0] * len(mlb.classes_)] * len(texts))  # Dummy labels since we are predicting
    trainer = Trainer(model=model)
    predictions = trainer.predict(dataset)
    predicted_probs = predictions.predictions
    predicted_labels = (predicted_probs > 0.5).astype(int)  # Apply threshold to get predicted labels
    return [{"id": id_, "labels": labels} for id_, labels in zip(ids, mlb.inverse_transform(predicted_labels))]

ar_texts = [item['text'] for item in ar_data]
bg_texts = [item['text'] for item in bg_data]
mk_texts = [item['text'] for item in mk_data]
en_texts = [item['text'] for item in en_data]
dev_texts = [item['text'] for item in dev_unlabel_data]

ar_ids = [item['id'] for item in ar_data]
bg_ids = [item['id'] for item in bg_data]
mk_ids = [item['id'] for item in mk_data]
en_ids = [item['id'] for item in en_data]
dev_ids = [item['id'] for item in dev_unlabel_data]

ar_predictions = predict_labels(ar_texts, ar_ids, model, tokenizer)
bg_predictions = predict_labels(bg_texts, bg_ids, model, tokenizer)
mk_predictions = predict_labels(mk_texts, mk_ids, model, tokenizer)
en_predictions = predict_labels(en_texts, en_ids, model, tokenizer)
dev_predictions = predict_labels(dev_texts, dev_ids, model, tokenizer)

# Save predictions to JSON files
with open('C:\\Users\\harih\\Downloads\\bert\\predictions_ar.json', 'w') as f:
    json.dump(ar_predictions, f)
with open('C:\\Users\\harih\\Downloads\\bert\\predictions_bg.json', 'w') as f:
    json.dump(bg_predictions, f)
with open('C:\\Users\\harih\\Downloads\\bert\\predictions_mk.json', 'w') as f:
    json.dump(mk_predictions, f)
with open('C:\\Users\\harih\\Downloads\\bert\\predictions_en.json', 'w') as f:
    json.dump(en_predictions, f)
with open('C:\\Users\\harih\\Downloads\\bert\\predictions_dev.json', 'w') as f:
    json.dump(dev_predictions, f)

print(f"AR Predictions: {ar_predictions}")
print(f"BG Predictions: {bg_predictions}")
print(f"MK Predictions: {mk_predictions}")
print(f"EN Predictions: {en_predictions}")
print(f"DEV Predictions: {dev_predictions}")
# Out:
# C:\Users\harih\AppData\Local\Temp\ipykernel_15656\314927799.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# AR Predictions: [{'id': '00001', 'labels': ('Smears',)}, {'id': '00002', 'labels': ()}, {'id': '00003', 'labels': ()}, {'id': '00004', 'labels': ()}, {'id': '00005', 'labels': ()}, {'id': '00006', 'labels': ('Smears',)}, {'id': '00008', 'labels': ()}, {'id': '00009', 'labels': ()}, {'id': '00011', 'labels': ()}, {'id': '00012', 'labels': ('Smears',)}, {'id': '00016', 'labels': ('Smears',)}, {'id': '00017
id': '00426', 'labels': ()}, {'id': '00431', 'labels': ()}, {'id': '00447', 'labels': ('Smears',)}, {'id': '00460', 'labels': ('Smears',)}, {'id': '00479', 'labels': ('Smears',)}, {'id': '00482', 'labels': ()}, {'id': '00483', 'labels': ('Smears',)}, {'id': '00490', 'labels': ()}, {'id': '00491', 'labels': ('Smears',)}, {'id': '00499', 'labels': ('Smears',)}, {'id': '00506', 'labels': ()}, {'id': '00541', 'labels': ()}, {'id': '00542', 'labels': ()}, {'id': '00573', 'labels': ()}]
# BG Predictions: [{'id': 'bg_mk_memes_83', 'labels': ('Smears',)}, {'id': 'bg_mk_memes_104', 'labels': ()}, {'id': 'bg_mk_memes_106', 'labels': ()}, {'id': 'bg_mk_memes_148', 'labels': ()}, {'id': 'bg_mk_memes_237', 'labels': ('Smears',)}, {'id': 'bg_mk_memes_246', 'labels': ('Loaded Language',)}, {'id': 'bg_mk_memes_247', 'labels': ('Smears',)}, {'id': 'bg_mk_memes_248', 'labels': ('Loaded Language',)}, {'id': 'bg_mk_memes_270', 'labels': ('Loaded Language',)}, {'id': 'bg_mk_memes_273', 'labels': ()}, {'id': 'bg_mk_memes_275', 'labels': ('Flag-waving',)}, {'id': 'bg_mk_memes_286', 'labels': ()}, {'id': 'bg_mk_memes_327', 'labels': ()}, {'id': 'bg_mk_memes_342', 'labels': ()}, {'id': 'bg_mk_memes_349', 'labels': ('Loaded Language',)}, {'id': 'bg_mk_memes_353', 'labels': ('Loaded Language',)}, {'id': 'bg_mk_memes_354', 'labels': ('Loaded Language',)}, {'id': 'bg_mk_memes_371', 'labels': ()}, {'id': 'bg_mk_memes_375', 'labels': ()}, {'id': 'bg_mk_memes_376', 'labels': ()}, {'id': 'bg_mk_memes_412', 'labels': ()}, {'id': 'bg_mk_memes_417', 'labels': ()}, {'id': 'bg_mk_memes_422', 'labels': ()}, {'id': 'bg_mk_memes_429', 'labels': ('Flag-waving',)}, {'id': 'bg_mk_memes_441', 'labels': ()}, {'id': 'bg_mk_memes_446', 'labels': ()}, {'id': 'bg_mk_memes_447', 'labels': ()}, {'id': 'bg_mk_memes_458', 'labels': ()}, {'id': 'bg_mk_memes_577', 'labels': ()}, {'id': 'bg_mk_memes_625', 'labels': ()}, {'id': 'bg_mk_memes_646', 'labels': ('Smears',)}, {'id': 'bg_mk_memes_647', 'labels': ()}, {'id': 'bg_mk_memes_648', 'labels': ('Loaded Language', 'Name calling/Labeling')}, {'id': 'bg_mk_memes_649', 'labels': ('Flag-waving',)}, {'id': 'bg_mk_memes_665', 'labels': ()}, {'id': 'bg_mk_memes_672', 'labels': ('Flag-waving', 'Loaded Language')}, {'id': 'bg_mk_memes_675', 'labels': ()}, {'id': 'bg_mk_memes_677', 'labels': ()}, {'id': 'bg_mk_memes_678', 'labels': ()}, {'id': 'bg_mk_memes_680', 'labels': ('Flag-waving',)}, {'id': 'bg_mk_memes_683', 'labels': ()}, {'id': 'bg_mk_memes_811', 'labels': ()}, {'id': 'bg_memes_77', 'labels': ()}, {'id': 'bg_memes_78', 'labels': ()}, {'id': 'bg_memes_79', 'labels': ()}, {'id': 'bg_memes_80', 'labels': ()}, {'id': 'bg_memes_81', 'labels': ()}, {'id': 'bg_memes_82', 'labels': ('Flag-waving',)}, {'id': 'bg_memes_83', 'labels': ()}, {'id': 'bg_memes_84', 'labels': ('Smears',)}, {'id': 'bg_memes_87', 'labels': ('Loaded Language',)}, {'id': 'bg_memes_88', 'labels': ('Loaded Language',)}, {'id': 'bg_memes_89', 'labels': ('Smears',)}, {'id': 'bg_memes_90', 'labels': ('Smears',)}, {'id': 'bg_memes_91', 'labels': ()}, {'id': 'bg_memes_92', 'labels': ()}, {'id': 'bg_memes_93', 'labels': ()}, {'id': 'bg_memes_94', 'labels': ()}, {'id': 'bg_memes_95', 'labels': ()}, {'id': 'bg_memes_96', 'labels': ('Loaded Language',)}, {'id': 'bg_memes_97', 'labels': ()}, {'id': 'bg_memes_98', 'labels': ('Flag-waving', 'Loaded Language')}, {'id': 'bg_memes_100', 'labels': ()}, {'id': 'bg_memes_101', 'labels': ()}, {'id': 'bg_memes_102', 'labels': ('Smears',)}, {'id': 'bg_memes_103', 'labels': ()}, {'id': 'bg_memes_104', 'labels': ()}, {'id': 'bg_memes_105', 'labels': ()}, {'id': 'bg_memes_106', 'labels': ()}, {'id': 'bg_memes_108', 'labels': ()}, {'id': 'bg_memes_109', 'labels': ('Flag-waving', 'Loaded Language')}, {'id': 'bg_memes_110', 'labels': ()}, {'id': 'bg_memes_111', 'labels': ()}, {'id': 'bg_memes_112', 'labels': ()}, {'id': 'bg_memes_113', 'labels': ()}, {'id': 'bg_memes_114', 'labels': ('Flag-waving', 'Loaded Language')}, {'id': 'bg_memes_115', 'labels': ()}, {'id': 'bg_memes_116', 'labels': ()}, {'id': 'bg_memes_117', 'labels': ('Smears',)}, {'id': 'bg_memes_118', 'labels': ('Loaded Language',)}, {'id': 'bg_memes_119', 'labels': ('Loaded Language', 'Name calling/Labeling')}, {'id': 'bg_memes_120', 'labels': ()}, {'id': 'bg_memes_121', 'labels': ()}, {'id': 'bg_memes_123', 'labels': ()}, {'id': 'bg_memes_124', 'labels': ()}, {'id': 'bg_memes_125', 'labels': ('Smears',)}, {'id': 'bg_memes_126', 'labels': ()}, {'id': 'bg_memes_127 ...
# MK Predictions: [{'id': 'mk_memes_2', 'labels': ()}, {'id': 'mk_memes_3', 'labels': ('Flag-waving', 'Loaded Language')}, {'id': 'mk_memes_4', 'labels': ('Flag-waving', 'Loaded Language')}, {'id': 'mk_memes_5', 'labels': ()}, {'id': 'mk_memes_6', 'labels': ()}, {'id': 'mk_memes_7', 'labels': ()}, {'id': 'mk_memes_9', 'labels': ('Loaded Language', 'Name calling/Labeling')}, {'id': 'mk_memes_10', 'labels': ('Loaded Language',)}, {'id': 'mk_memes_11', 'labels': ()}, {'id': 'mk_memes_13', 'labels': ()}, {'id': 'mk_memes_14', 'labels': ()}, {'id': 'mk_memes_15', 'labels': ()}, {'id': 'mk_memes_16', 'labels': ()}, {'id': 'mk_memes_17', 'labels': ('Loaded Language',)}, {'id': 'mk_memes_19', 'labels': ('Loaded Language',)}, {'id': 'mk_memes_20', 'labels': ('Smears',)}, {'id': 'mk_memes_21', 'labels': ()}, {'id': 'mk_memes_22', 'labels': ()}, {'id': 'mk_memes_23', 'labels': ()}, {'id': 'mk_memes_25', 'labels': ()}, {'id': 'mk_memes_26', 'labels': ()}, {'id': 'mk_memes_28', 'labels': ()}, {'id': 'mk_memes_29', 'labels': ()}, {'id': 'mk_memes_30', 'labels': ()}, {'id': 'mk_memes_31', 'labels': ()}, {'id': 'mk_memes_32', 'labels': ('Flag-waving',)}, {'id': 'mk_memes_33', 'labels': ()}, {'id': 'mk_memes_34', 'labels': ()}, {'id': 'mk_memes_35', 'labels': ()}, {'id': 'mk_memes_36', 'labels': ()}, {'id': 'mk_memes_37', 'labels': ('Smears',)}, {'id': 'mk_memes_38', 'labels': ()}, {'id': 'mk_memes_39', 'labels': ()}, {'id': 'mk_memes_42', 'labels': ('Flag-waving', 'Loaded Language')}, {'id': 'mk_memes_43', 'labels': ('Flag-waving', 'Loaded Language')}, {'id': 'mk_memes_45', 'labels': ()}, {'id': 'mk_memes_46', 'labels': ('Flag-waving',)}, {'id': 'mk_memes_47', 'labels': ('Flag-waving', 'Loaded Language')}, {'id': 'mk_memes_48', 'labels': ('Flag-waving',)}, {'id': 'mk_memes_49', 'labels': ('Flag-waving',)}, {'id': 'mk_memes_50', 'labels': ('Loaded Language',)}, {'id': 'mk_memes_51', 'labels': ('Loaded Language',)}, {'id': 'mk_memes_52', 'labels': ()}, {'id': 'mk_memes_53', 'labels': ()}, {'id': 'mk_memes_54', 'labels': ('Flag-waving',)}, {'id': 'mk_memes_55', 'labels': ()}, {'id': 'mk_memes_56', 'labels': ()}, {'id': 'mk_memes_57', 'labels': ()}, {'id': 'mk_memes_59', 'labels': ()}, {'id': 'mk_memes_60', 'labels': ()}, {'id': 'mk_memes_61', 'labels': ()}, {'id': 'mk_memes_62', 'labels': ('Loaded Language',)}, {'id': 'mk_memes_63', 'labels': ('Loaded Language', 'Name calling/Labeling')}, {'id': 'mk_memes_64', 'labels': ()}, {'id': 'mk_memes_65', 'labels': ('Loaded Language',)}, {'id': 'mk_memes_66', 'labels': ()}, {'id': 'mk_memes_69', 'labels': ('Smears',)}, {'id': 'mk_memes_70', 'labels': ()}, {'id': 'mk_memes_71', 'labels': ()}, {'id': 'mk_memes_72', 'labels': ('Smears',)}, {'id': 'mk_memes_73', 'labels': ()}, {'id': 'mk_memes_74', 'labels': ()}, {'id': 'mk_memes_75', 'labels': ()}, {'id': 'mk_memes_76', 'labels': ()}, {'id': 'mk_memes_77', 'labels': ()}, {'id': 'mk_memes_78', 'labels': ('Smears',)}, {'id': 'mk_memes_79', 'labels': ('Loaded Language',)}, {'id': 'mk_memes_80', 'labels': ()}, {'id': 'mk_memes_81', 'labels': ()}, {'id': 'mk_memes_82', 'labels': ()}, {'id': 'mk_memes_84', 'labels': ()}, {'id': 'mk_memes_85', 'labels': ()}, {'id': 'mk_memes_86', 'labels': ()}, {'id': 'mk_memes_87', 'labels': ()}, {'id': 'mk_memes_88', 'labels': ()}, {'id': 'mk_memes_89', 'labels': ()}, {'id': 'mk_memes_90', 'labels': ('Loaded Language',)}, {'id': 'mk_memes_91', 'labels': ()}, {'id': 'mk_memes_92', 'labels': ()}, {'id': 'mk_memes_94', 'labels': ('Flag-waving',)}, {'id': 'mk_memes_95', 'labels': ('Loaded Language',)}, {'id': 'mk_memes_96', 'labels': ('Flag-waving', 'Loaded Language')}, {'id': 'mk_memes_100', 'labels': ()}, {'id': 'mk_memes_101', 'labels': ()}, {'id': 'mk_memes_102', 'labels': ()}, {'id': 'mk_memes_103', 'labels': ()}, {'id': 'mk_memes_104', 'labels': ()}, {'id': 'mk_memes_105', 'labels': ()}, {'id': 'mk_memes_106', 'labels': ('Flag-waving',)}, {'id': 'mk_memes_109', 'labels': ('Loaded Language',)}, {'id': 'mk_memes_110', 'labels': (' ...
# EN Predictions: [{'id': '79056', 'labels': ()}, {'id': '79095', 'labels': ()}, {'id': '63268', 'labels': ()}, {'id': '67985', 'labels': ('Loaded Language',)}, {'id': '64747', 'labels': ()}, {'id': '79845', 'labels': ()}, {'id': '65953', 'labels': ()}, {'id': '67431', 'labels': ('Flag-waving', 'Loaded Language')}, {'id': '66132', 'labels': ('Smears',)}, {'id': '78882', 'labels': ()}, {'id': '77755', 'labels': ()}, {'id': '68008', 'labels': ('Loaded Language',)}, {'id': '68419', 'labels': ()}, {'id': '67167', 'labels': ('Flag-waving',)}, {'id': '65798', 'labels': ()}, {'id': '69411', 'labels': ('Appeal to authority',)}, {'id': '63831', 'labels': ()}, {'id': '63412', 'labels': ()}, {'id': '64967', 'labels': ()}, {'id': '70057', 'labels': ()}, {'id': '70044', 'labels': ()}, {'id': '77767', 'labels': ('
125', 'labels': ()}, {'id': '66288', 'labels': ()}, {'id': '71706', 'labels': ()}, {'id': '77566', 'labels': ()}, {'id': '77632', 'labels': ()}, {'id': '78153', 'labels': ()}, {'id': '77779', 'labels': ()}, {'id': '70773', 'labels': ()}, {'id': '68820', 'labels': ('Loaded Language',)}, {'id': '65736', 'labels': ()}, {'id': '77579', 'labels': ()}, {'id': '77001', 'labels': ('Flag-waving',)}, {'id': '64299', 'labels': ()}, {'id': '71785', 'labels': ('Flag-waving',)}, {'id': '77295', 'labels': ()}, {'id': '75891', 'labels': ()}, {'id': '75858', 'labels': ('Loaded Language',)}, {'id': '69869', 'labels': ()}, {'id': '68238', 'labels': ()}, {'id': '71234', 'labels': ()}, {'id': '67987', 'labels': ('Flag-waving',)}, {'id': '67841', 'labels': ()}, {'id': '66758', 'labels': ()}, {'id': '76107', 'labels': ()}, {'id': '64854', 'labels': ()}, {'id': '65839', 'labels': ('Flag-waving',)}, {'id': '66623', 'labels': ()}, {'id': '67946', 'labels': ()}, {'id': '76426', 'labels': ()}, {'id': '66891', 'labels': ()}, {'id': '66789', 'labels': ()}, {'id': '66770', 'labels': ('Flag-waving',)}, {'id': '70029', 'labels': ('Loaded Language', 'Name calling/Labeling')}, {'id': '69821', 'labels': ()}, {'id': '63898', 'labels': ()}, {'id': '64568', 'labels': ('Smears',)}, {'id': '70001', 'labels': ('Loaded Language',)}, {'id': '65158', 'labels': ()}, {'id': '64873', 'labels': ('Loaded Language',)}, {'id': '77641', 'labels': ()}, {'id': '70364', 'labels': ()}, {'id': '64084', 'labels': ()}, {'id': '66045', 'labels': ()}, {'id': '64472', 'labels': ()}, {'id': '69618', 'labels': ('Loaded Language',)}, {'id': '76692', 'labels': ()}, {'id': '70376', 'labels': ()}, {'id': '67411', 'labels': ()}, {'id': '64673', 'labels': ()}, { ...

# %%
# !python C:\Users\harih\Downloads\subtask_1_2a.py -g C:\Users\harih\Downloads\gold_labels_ar_bg_md_version2\test_subtask1_bg.json -p C:\Users\harih\Downloads\bert\predictions_bg.json
# Out:
# f1_h=0.19551	prec_h=0.41223	rec_h=0.12814

# %%
# !python C:\Users\harih\Downloads\subtask_1_2a.py -g C:\Users\harih\Downloads\gold_labels_ar_bg_md_version2\test_subtask1_ar.json -p C:\Users\harih\Downloads\bert\predictions_ar.json
# Out:
# f1_h=0.23113	prec_h=0.35252	rec_h=0.17193

# %%
# !python C:\Users\harih\Downloads\subtask_1_2a.py -g C:\Users\harih\Downloads\dev_gold_labels\dev_gold_labels\dev_subtask1_en.json -p C:\Users\harih\Downloads\bert\predictions_dev.json
# Out:
# f1_h=0.10596	prec_h=0.45642	rec_h=0.05994

# %%
# !python C:\Users\harih\Downloads\subtask_1_2a.py -g C:\Users\harih\Downloads\gold_labels_ar_bg_md_version2\test_subtask1_md.json -p C:\Users\harih\Downloads\bert\predictions_mk.json
# Out:
# f1_h=0.18898	prec_h=0.32727	rec_h=0.13284
